# %%
# !pip install unsloth
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 MB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 MB 14.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 23.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.8/73.8 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 95.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 29.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 68.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 82.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 82.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 19.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 MB 14.4 MB/s eta 0:00:00
# ...

# %%
# !pip install --no-deps xformers "trl<0.25.0" transformers datasets accelerate

# %%
import torch
from unsloth import FastLanguageModel
from trl import SFTTrainer
from transformers import TrainingArguments

print(f"GPU detected: {torch.cuda.get_device_name(0)}")
print("Unsloth and SFTTrainer imported successfully!")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# GPU detected: Tesla T4
# Unsloth and SFTTrainer imported successfully!

# %%
# %run data_gen.py
# Out:
# Successfully generated 16 rows in banking_sft.jsonl

# %%
# %run fine_tuner.py
# Out:
# Transformers version: 5.5.0
# TRL version: 0.24.0
# ==((====))==  Unsloth 2026.8.18: Fast Mistral patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# Unsloth 2026.8.18 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.
# Generating train split: 0 examples [00:00, ? examples/s]
# ...
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/16 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 16 | Num Epochs = 30 | Total steps = 60
# ...

# %%
# !sudo apt-get install -y pciutils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpci3 pci.ids
# The following NEW packages will be installed:
#   libpci3 pci.ids pciutils
# 0 upgraded, 3 newly installed, 0 to remove and 67 not upgraded.
# Need to get 343 kB of archives.
# After this operation, 1,581 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 pci.ids all 0.0~2022.01.22-1ubuntu0.1 [251 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpci3 amd64 1:3.7.0-6 [28.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 pciutils amd64 1:3.7.0-6 [63.6 kB]
# Fetched 343 kB in 0s (2,740 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# ...

# %%
# !sudo apt-get install zstd
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 67 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 0s (5,911 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package zstd.
# ...

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !nohup ollama serve > ollama.log 2>&1 &

# %%
# !ollama pull phi3

# %%
# !ollama run phi3 "Why is the sky blue?"
# Out:
# The sky appears blue to the human eye under clear, sunny conditions primari
# primarily due to a phenomenon called Rayleigh scattering. Sunlight, which i
# is white light composed of various colors, travels through Earth's atmosphe
# atmosphere and collides with molecules and small particles. When the sun is
# is high in the sky, the light is scattered in different directions. Since b
# blue light scatters more than other colors due to its shorter, smaller wave
# wavelength, it'nervously scatters in all directions. This widespread scatte
# scattering of blue light into our eyes is what makes the sky look blue.
#
#
# Additionally, during the day, when the sun is higher in the sky, the path t
# through the atmosphere is shorter, which results in the light being more li
# likely to be scattered and blue being the dominant wavelength we perceive.
# At sunrise and sunset, the sun's light passes through a greater thickness o
# ...

# %%
# %ls -la banking_model_gguf_gguf/
# Out:
# total 2264588
# drwxr-xr-x 2 root root       4096 Aug 18 08:07 ./
# drwxr-xr-x 1 root root       4096 Aug 18 08:16 ../
# -rw-r--r-- 1 root root        333 Aug 18 08:07 Modelfile
# -rw-r--r-- 1 root root 2318919456 Aug 18 08:07 phi-3-mini-4k-instruct.Q4_K_M.gguf

# %%
# !ollama create banking-agent -f ./Modelfile

# %%
# !ollama run banking-agent
# Out:
# >>> Send a message (/? for help)/?
# Available Commands:
#   /set            Set session variables
#   /show           Show model information
#   /load <model>   Load a session or model
#   /save <model>   Save your current session
#   /clear          Clear session context
#   /bye            Exit
#   /?, /help       Help for a command
#   /? shortcuts    Help for keyboard shortcuts
#
# Use """ to begin a multi-line message.
#
# >>> Send a message (/? for help)What
# ...  doe
# ... s AP
# ... Y st
# ... and
# ... for?
# ...
# """What does APY stand for?"""
# APY stands for Annual Percentage Yield. It reflects the total amount of int
# interest you would earn in one year if you were to continuously deposit $10
# $100 into a savings account. It takes into account the effect of compoundin
# compounding interest, which can increase your earnings over time.
#
#
# >>> Send a message (/? for help)"""W
# ... hat
# ... does
# ...  APY
# ...  sta
# ... nd f
# ... or?"
# ... ""
# ...
